# %% [markdown]
# <a href="https://colab.research.google.com/github/osalex800/Analisis-y-visualizacion-de-datos/blob/main/Estadistica_descriptiva.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# La estadística descriptiva es una herramienta fundamental para el análisis de datos, ya que permite organizar, resumir y describir la información de manera clara. En esta práctica, utilizando Google Colab y el lenguaje R, se aplican distintos métodos estadísticos y gráficos con el fin de comprender mejor el comportamiento de un conjunto de datos y facilitar su interpretación.

# %%
install.packages("readxl")
library("readxl")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
datos <- read_excel("/base_datos_helados_500_registros.xlsx")
head(datos)
# Out:
#   Helado   Estatura peso     Ingresos Educacion Hijos
# 1 Limón    1.806198 89.95462 1601.832 4         1
# 2 Maracuyá 1.854355 85.18091 1740.319 2         0
# 3 Mora     1.640591 71.52460 1432.034 1         4
# 4 Coco     1.559733 86.17954 2068.077 1         2
# 5 Fresa    1.854728 59.88186 1639.082 1         0
# 6 Mora     1.653885 86.44549 2026.320 2         2

# %%
mean(datos$Estatura)
# Out:
# [1] 1.734004

# %%
apply(as.matrix(datos[,2:4]), 2,mean)
# Out:
#    Estatura        peso    Ingresos
#    1.734004   74.482674 1700.416694

# %%
lapply(datos[,2:4], mean)
# Out:
# $Estatura
# [1] 1.734004
#
# $peso
# [1] 74.48267
#
# $Ingresos
# [1] 1700.417

# %%
unlist(lapply(datos[,2:4], mean)) # unlist -> para no verlo como lista
# Out:
#    Estatura        peso    Ingresos
#    1.734004   74.482674 1700.416694

# %%
median(datos$Estatura)
# Out:
# [1] 1.739476

# %%
apply(as.matrix(datos[,2:4]),2, median)
# Out:
#    Estatura        peso    Ingresos
#    1.739476   74.413605 1713.799500

# %%
unlist(lapply(datos[,2:4], median)) # unlist -> para no verlo como lista
# Out:
#    Estatura        peso    Ingresos
#    1.739476   74.413605 1713.799500

# %%
var(datos$Estatura)
# Out:
# [1] 0.01016447

# %%
sd(datos$peso)
# Out:
# [1] 11.62325

# %%
apply(as.matrix(datos[,2:4]), 2, sd)
# Out:
#   Estatura       peso   Ingresos
#   0.100819  11.623248 291.202692

# %%
unlist(lapply(datos[,2:4], sd)) # unlist -> para no verlo como lista
# Out:
#   Estatura       peso   Ingresos
#   0.100819  11.623248 291.202692

# %%
quantile(datos$Estatura)
# Out:
#       0%      25%      50%      75%     100%
# 1.550751 1.648060 1.739476 1.822418 1.899272

# %%
quantile(datos$Estatura, probs = 0.25) #-> Si solo deceamos uno en específico.
# Out:
#     25%
# 1.64806

# %%
quantile(datos$Estatura, probs = c(0.25, 0.75)) #-> dos o mas utilizamos c(valor1, valor2,...)
# Out:
#      25%      75%
# 1.648060 1.822418

# %%
quantile(datos$Estatura, probs = 0.20)
# Out:
#      20%
# 1.630622

# %%
quantile(datos$Estatura, probs = c(0.10, 0.15 ,0.20))
# Out:
#      10%      15%      20%
# 1.593158 1.610960 1.630622

# %%
summary(datos)
# Out:
#     Helado             Estatura          peso          Ingresos
#  Length:500         Min.   :1.551   Min.   :55.08   Min.   :1202
#  Class :character   1st Qu.:1.648   1st Qu.:64.11   1st Qu.:1449
#  Mode  :character   Median :1.739   Median :74.41   Median :1714
#                     Mean   :1.734   Mean   :74.48   Mean   :1700
#                     3rd Qu.:1.822   3rd Qu.:84.46   3rd Qu.:1955
#                     Max.   :1.899   Max.   :94.93   Max.   :2199
#    Educacion        Hijos
#  Min.   :1.00   Min.   :0.000
#  1st Qu.:2.00   1st Qu.:1.000
#  Median :3.00   Median :2.000
#  Mean   :2.58   Mean   :2.088
#  3rd Qu.:4.00   3rd Qu.:3.000
#  Max.   :4.00   Max.   :4.000

# %%
datos$Helado = as.factor(datos$Helado)
summary(datos)
# Out:
#        Helado      Estatura          peso          Ingresos      Educacion
#  Chocolate:73   Min.   :1.551   Min.   :55.08   Min.   :1202   Min.   :1.00
#  Coco     :74   1st Qu.:1.648   1st Qu.:64.11   1st Qu.:1449   1st Qu.:2.00
#  Fresa    :69   Median :1.739   Median :74.41   Median :1714   Median :3.00
#  Limón    :84   Mean   :1.734   Mean   :74.48   Mean   :1700   Mean   :2.58
#  Maracuyá :59   3rd Qu.:1.822   3rd Qu.:84.46   3rd Qu.:1955   3rd Qu.:4.00
#  Mora     :59   Max.   :1.899   Max.   :94.93   Max.   :2199   Max.   :4.00
#  Vainilla :82
#      Hijos
#  Min.   :0.000
#  1st Qu.:1.000
#  Median :2.000
#  Mean   :2.088
#  3rd Qu.:3.000
#  Max.   :4.000

# %% [markdown]
# La práctica de estadística descriptiva que se propone en la página de RPubs tiene como objetivo enseñarte a explorar, resumir y describir un conjunto de datos paso a paso utilizando R (aunque el documento está alojado en RPubs, los mismos pasos pueden reproducirse en Google Colab configurando R). Esto implica:
#
# Importar y cargar correctamente los datos (por ejemplo desde un archivo CSV o similar) para trabajar con tu conjunto de datos en Colab.
#
# Explorar la estructura de los datos, identificando cuántas observaciones y variables existen, y verificando tipos de datos (numéricos vs. categóricos).
#
# Calcular estadísticos descriptivos básicos, como medidas de tendencia central (media, mediana) y medidas de dispersión (desviación estándar, rango, cuartiles), lo cual te da una primera impresión de la distribución de tus variables.
